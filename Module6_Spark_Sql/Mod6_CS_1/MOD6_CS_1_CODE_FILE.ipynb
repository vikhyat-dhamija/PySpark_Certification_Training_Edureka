# %%
import pyspark.sql.functions as F
import os
from pyspark.sql import SparkSession, SQLContext
from pyspark import SparkContext, SparkConf


#Spark session is being created
#Configuration of the Spark Session
app_name="instacart"
conf = SparkConf()  # create the configuration
conf.set('spark.driver.extraClassPath', "/usr/share/cmf/common_jars/mysql-connector-java-5.1.15.jar")  # set the spark.jars
conf.set('spark.executor.extraClassPath', "/usr/share/cmf/common_jars/mysql-connector-java-5.1.15.jar")

#Spark Session object
spark = SparkSession.builder.config(conf=conf).appName(app_name).getOrCreate()

# %%
#1. Load data into Spark DataFrame

orders = spark.read.csv("/user/edureka_960126/instacart/orders.csv",inferSchema=True,header=True)
products=spark.read.csv("/user/edureka_960126/instacart/products.csv",inferSchema=True,header=True)
departments=spark.read.csv("/user/edureka_960126/instacart/departments.csv",inferSchema=True,header=True)
aisles=spark.read.csv("/user/edureka_960126/instacart/aisles.csv",inferSchema=True,header=True)
order_products__prior=spark.read.csv("/user/edureka_960126/instacart/order_products__prior.csv",inferSchema=True,header=True)
order_products__train=spark.read.csv("/user/edureka_960126/instacart/order_products__train.csv",inferSchema=True,header=True)

orders.createOrReplaceTempView("orders")
products.createOrReplaceTempView("products")
departments.createOrReplaceTempView("departments")
aisles.createOrReplaceTempView("aisles")
order_products__prior.createOrReplaceTempView("order_products__prior")
order_products__train.createOrReplaceTempView("order_products__train")

#sql_df = spark.sql('Select * From orders')
#sql_df.show(10)
orders.show(10)
products.show(10)
departments.show(100)
aisles.show(100)
order_products__prior.show(10)
order_products__train.show(10)
# Out:
# +--------+-------+--------+------------+---------+-----------------+----------------------+
# |order_id|user_id|eval_set|order_number|order_dow|order_hour_of_day|days_since_prior_order|
# +--------+-------+--------+------------+---------+-----------------+----------------------+
# | 2539329|      1|   prior|           1|        2|                8|                  null|
# | 2398795|      1|   prior|           2|        3|                7|                  15.0|
# |  473747|      1|   prior|           3|        3|               12|                  21.0|
# | 2254736|      1|   prior|           4|        4|                7|                  29.0|
# |  431534|      1|   prior|           5|        4|               15|                  28.0|
# | 3367565|      1|   prior|           6|        2|                7|                  19.0|
# |  550135|      1|   prior|           7|        1|                9|                  20.0|
# | 3108588|      1|   prior|           8|        1|               14|                  14.0|
# | 2295261|      1|   prior|           9|        1|               16|                   0.0|
# | 2550362|      1|   prior|          10|        4|                8|                  30.0|
# +--------+-------+--------+------------+---------+-----------------+----------------------+
# only showing top 10 rows
#
# +----------+--------------------+--------+-------------+
# |product_id|        product_name|aisle_id|department_id|
# +----------+--------------------+--------+-------------+
# |         1|Chocolate Sandwic...|      61|           19|
# |         2|    All-Seasons Salt|     104|           13|
# |         3|Robust Golden Uns...|      94|            7|
# |         4|Smart Ones Classi...|      38|            1|
# |         5|Green Chile Anyti...|       5|           13|
# |         6|        Dry Nose Oil|      11|           11|
# |         7|Pure Coconut Wate...|      98|            7|
# |         8|Cut Russet Potato...|     116|            1|
# |         9|Light Strawberry ...|     120|           16|
# |        10|Sparkling Orange ...|     115|            7|
# +----------+--------------------+--------+-------------+
# only showing top 10 rows
#
# +-------------+---------------+
# |department_id|     department|
# +-------------+---------------+
# |            1|         frozen|
# |            2|          other|
# |            3|         bakery|
# |            4|        produce|
# |            5|        alcohol|
# |            6|  international|
# |            7|      beverages|
# |            8|           pets|
# |            9|dry goods pasta|
# |           10|           bulk|
# |           11|  personal care|
# |           12|   meat seafood|
# |           13|         pantry|
# |           14|      breakfast|
# |           15|   canned goods|
# |           16|     dairy eggs|
# |           17|      household|
# |           18|         babies|
# |           19|         snacks|
# |           20|           deli|
# |           21|        missing|
# +-------------+---------------+
#
# +--------+--------------------+
# |aisle_id|               aisle|
# +--------+--------------------+
# |       1|prepared soups sa...|
# |       2|   specialty cheeses|
# |       3| energy granola bars|
# |       4|       instant foods|
# |       5|marinades meat pr...|
# |       6|               other|
# |       7|       packaged meat|
# |       8|     bakery desserts|
# |       9|         pasta sauce|
# |      10|    kitchen supplies|
# |      11|    cold flu allergy|
# |      12|         fresh pasta|
# |      13|      prepared meals|
# |      14|tofu meat alterna...|
# |      15|    packaged seafood|
# |      16|         fresh herbs|
# |      17|  baking ingredients|
# |      18|bulk dried fruits...|
# |      19|       oils vinegars|
# |      20|        oral hygiene|
# |      21|     packaged cheese|
# |      22|           hair care|
# |      23|       popcorn jerky|
# |      24|        fresh fruits|
# |      25|                soap|
# |      26|              coffee|
# |      27|       beers coolers|
# |      28|           red wines|
# |      29|honeys syrups nec...|
# |      30|        latino foods|
# |      31|        refrigerated|
# |      32|    packaged produce|
# |      33|        kosher foods|
# |      34| frozen meat seafood|
# |      35|     poultry counter|
# |      36|              butter|
# |      37|       ice cream ice|
# |      38|        frozen meals|
# |      39|     seafood counter|
# |      40|       dog food care|
# |      41|       cat food care|
# |      42|frozen vegan vege...|
# |      43|          buns rolls|
# |      44|        eye ear care|
# |      45|     candy chocolate|
# |      46|            mint gum|
# |      47|vitamins supplements|
# |      48|breakfast bars pa...|
# |      49|    packaged poultry|
# |      50|fruit vegetable s...|
# |      51|preserved dips sp...|
# |      52|    frozen breakfast|
# |      53|               cream|
# |      54|         paper goods|
# |      55|         shave needs|
# |      56|       diapers wipes|
# |      57|             granola|
# |      58|frozen breads doughs|
# |      59|  canned meals beans|
# |      60|   trash bags liners|
# |      61|       cookies cakes|
# |      62|         white wines|
# |      63|grains rice dried...|
# |      64|energy sports drinks|
# |      65|protein meal repl...|
# |      66|         asian foods|
# |      67|fresh dips tapenades|
# |      68|bulk grains rice ...|
# |      69| soup broth bouillon|
# |      70|           digestion|
# |      71|refrigerated pudd...|
# |      72|          condiments|
# |      73|         facial care|
# |      74|     dish detergents|
# |      75|             laundry|
# |      76|        indian foods|
# |      77|         soft drinks|
# |      78|            crackers|
# |      79|        frozen pizza|
# |      80|          deodorants|
# |      81|canned jarred veg...|
# |      82|    baby accessories|
# |      83|    fresh vegetables|
# |      84|                milk|
# |      85|        food storage|
# |      86|                eggs|
# |      87|      more household|
# |      88|             spreads|
# |      89|salad dressing to...|
# |      90|   cocoa drink mixes|
# |      91|     soy lactosefree|
# |      92|   baby food formula|
# |      93|    breakfast bakery|
# |      94|                 tea|
# |      95| canned meat seafood|
# |      96|          lunch meat|
# |      97|baking supplies d...|
# |      98|       juice nectars|
# |      99|canned fruit appl...|
# |     100|             missing|
# +--------+--------------------+
# only showing top 100 rows
#
# +--------+----------+-----------------+---------+
# |order_id|product_id|add_to_cart_order|reordered|
# +--------+----------+-----------------+---------+
# |       2|     33120|                1|        1|
# |       2|     28985|                2|        1|
# |       2|      9327|                3|        0|
# |       2|     45918|                4|        1|
# |       2|     30035|                5|        0|
# |       2|     17794|                6|        1|
# |       2|     40141|                7|        1|
# |       2|      1819|                8|        1|
# |       2|     43668|                9|        0|
# |       3|     33754|                1|        1|
# +--------+----------+-----------------+---------+
# only showing top 10 rows
#
# +--------+----------+-----------------+---------+
# |order_id|product_id|add_to_cart_order|reordered|
# +--------+----------+-----------------+---------+
# |       1|     49302|                1|        1|
# |       1|     11109|                2|        1|
# |       1|     10246|                3|        0|
# |       1|     49683|                4|        0|
# |       1|     43633|                5|        1|
# |       1|     13176|                6|        0|
# |       1|     47209|                7|        0|
# |       1|     22035|                8|        1|
# |      36|     39612|                1|        0|
# |      36|     19660|                2|        1|
# +--------+----------+-----------------+---------+
# only showing top 10 rows

# %%
#2. Merge all the data frames based on the common key and create a single DataFrame 

#First products merged with aisles and departments

sdf=spark.sql('select o.order_id , o.user_id , o.eval_set , o.order_number ,o.order_dow ,o.order_hour_of_day ,o.days_since_prior_order , op.order_id , op.add_to_cart_order , op.reordered , p.product_id , p.product_name , p.aisle_id ,p.department_id , d.department , a.aisle from  orders o , order_products__prior op , products p , departments d, aisles a where o.order_id = op.order_id  and op.product_id = p.product_id and  p.department_id = d.department_id and p.aisle_id = a.aisle_id')

sdf.show(100)
# Out:
# +--------+-------+--------+------------+---------+-----------------+----------------------+--------+-----------------+---------+----------+--------------------+--------+-------------+---------------+--------------------+
# |order_id|user_id|eval_set|order_number|order_dow|order_hour_of_day|days_since_prior_order|order_id|add_to_cart_order|reordered|product_id|        product_name|aisle_id|department_id|     department|               aisle|
# +--------+-------+--------+------------+---------+-----------------+----------------------+--------+-----------------+---------+----------+--------------------+--------+-------------+---------------+--------------------+
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|                1|        0|     38650| Organic Red Lentils|      63|            9|dry goods pasta|grains rice dried...|
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|                2|        0|     25659|Organic Coconut Milk|      91|           16|     dairy eggs|     soy lactosefree|
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|                3|        1|     35951|Organic Unsweeten...|      91|           16|     dairy eggs|     soy lactosefree|
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|                4|        1|     34197|           Goat Milk|      84|           16|     dairy eggs|                milk|
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|                5|        1|     11712|Cage Free Large W...|      86|           16|     dairy eggs|                eggs|
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|                6|        1|     26940|Organic Large Gre...|      83|            4|        produce|    fresh vegetables|
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|                7|        0|     48364|         Sweet Onion|      83|            4|        produce|    fresh vegetables|
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|                8|        1|     21903|Organic Baby Spinach|     123|            4|        produce|packaged vegetabl...|
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|                9|        1|     14881|Organic Yukon Sel...|     129|            1|         frozen|frozen appetizers...|
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|               10|        1|     34720|Avocado Oil, Refined|      19|           13|         pantry|       oils vinegars|
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|               11|        1|      1158|        Mango Chunks|     116|            1|         frozen|      frozen produce|
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|               12|        0|     26606|Simply White Natu...|      20|           11|  personal care|        oral hygiene|
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|               13|        1|     47209|Organic Hass Avocado|      24|            4|        produce|        fresh fruits|
# |     148|  41523|   prior|          27|        2|               17|                   5.0|     148|               14|        1|     21614|Crackers Harvest ...|      78|           19|         snacks|            crackers|
# |     463|  92093|   prior|          18|        1|               17|                   5.0|     463|                1|        0|     36051|       Glass Cleaner|     114|           17|      household|   cleaning products|
# |     471|  52745|   prior|           5|        6|               18|                  30.0|     471|                1|        0|      8193|       Russet Potato|      83|            4|        produce|    fresh vegetables|
# |     471|  52745|   prior|           5|        6|               18|                  30.0|     471|                2|        0|     10814|Applewood Smoked ...|     106|           12|   meat seafood|hot dogs bacon sa...|
# |     471|  52745|   prior|           5|        6|               18|                  30.0|     471|                3|        0|     40585|Gade A Natural So...|     108|           16|     dairy eggs|other creams cheeses|
# |     471|  52745|   prior|           5|        6|               18|                  30.0|     471|                4|        0|     16185|Sharp Cheddar Cheese|      21|           16|     dairy eggs|     packaged cheese|
# |     471|  52745|   prior|           5|        6|               18|                  30.0|     471|                5|        0|      5337|Monterey Jack Cheese|      21|           16|     dairy eggs|     packaged cheese|
# |     471|  52745|   prior|           5|        6|               18|                  30.0|     471|                6|        1|     19415|Roasted Tomato Sa...|      51|           13|         pantry|preserved dips sp...|
# |     471|  52745|   prior|           5|        6|               18|                  30.0|     471|                7|        0|     17835|Thin & Light Tort...|     107|           19|         snacks|      chips pretzels|
# |     471|  52745|   prior|           5|        6|               18|                  30.0|     471|                8|        0|     35838|          Cumin Seed|     104|           13|         pantry|   spices seasonings|
# |     496|   7580|   prior|           3|        5|               12|                   4.0|     496|                1|        0|       742|Organic Raw Cocon...|      72|           13|         pantry|          condiments|
# |     496|   7580|   prior|           3|        5|               12|                   4.0|     496|                2|        0|     14992|         Green Beans|      83|            4|        produce|    fresh vegetables|
# |     496|   7580|   prior|           3|        5|               12|                   4.0|     496|                3|        1|     17461|Air Chilled Organ...|      35|           12|   meat seafood|     poultry counter|
# |     833| 183333|   prior|           3|        6|               15|                   4.0|     833|                1|        1|     30639|Organic Orange Juice|      98|            7|      beverages|       juice nectars|
# |     833| 183333|   prior|           3|        6|               15|                   4.0|     833|                2|        1|       329|Organic Whole Gra...|      84|           16|     dairy eggs|                milk|
# |     833| 183333|   prior|           3|        6|               15|                   4.0|     833|                3|        0|      2099|Natural Cane Turb...|      17|           13|         pantry|  baking ingredients|
# |     833| 183333|   prior|           3|        6|               15|                   4.0|     833|                4|        0|     47209|Organic Hass Avocado|      24|            4|        produce|        fresh fruits|
# |     833| 183333|   prior|           3|        6|               15|                   4.0|     833|                5|        0|     25323|Calming Shampoo T...|      22|           11|  personal care|           hair care|
# |     833| 183333|   prior|           3|        6|               15|                   4.0|     833|                6|        1|      1991|Organic Lemonade ...|      98|            7|      beverages|       juice nectars|
# |    1088|  63293|   prior|           8|        0|               11|                   7.0|    1088|                1|        1|     40761|   Pomegranate Seeds|     123|            4|        produce|packaged vegetabl...|
# |    1088|  63293|   prior|           8|        0|               11|                   7.0|    1088|                2|        1|     46667| Organic Ginger Root|      83|            4|        produce|    fresh vegetables|
# |    1088|  63293|   prior|           8|        0|               11|                   7.0|    1088|                3|        1|     10017|       Tilapia Filet|      39|           12|   meat seafood|     seafood counter|
# |    1088|  63293|   prior|           8|        0|               11|                   7.0|    1088|                4|        1|     39190|Vanilla Unsweeten...|      91|           16|     dairy eggs|     soy lactosefree|
# |    1088|  63293|   prior|           8|        0|               11|                   7.0|    1088|                5|        1|      5262|Brown Extra Large...|      86|           16|     dairy eggs|                eggs|
# |    1088|  63293|   prior|           8|        0|               11|                   7.0|    1088|                6|        1|     45066|    Honeycrisp Apple|      24|            4|        produce|        fresh fruits|
# |    1088|  63293|   prior|           8|        0|               11|                   7.0|    1088|                7|        1|     46676|Total 0% Nonfat G...|     120|           16|     dairy eggs|              yogurt|
# |    1088|  63293|   prior|           8|        0|               11|                   7.0|    1088|                8|        1|     27966| Organic Raspberries|     123|            4|        produce|packaged vegetabl...|
# |    1088|  63293|   prior|           8|        0|               11|                   7.0|    1088|                9|        1|     24184|         Red Peppers|      83|            4|        produce|    fresh vegetables|
# |    1088|  63293|   prior|           8|        0|               11|                   7.0|    1088|               10|        1|     39040|Organic Sliced Cr...|     123|            4|        produce|packaged vegetabl...|
# |    1238|  77115|   prior|           4|        1|               11|                   8.0|    1238|                1|        1|     25476|Classic Recipe Ch...|      69|           15|   canned goods| soup broth bouillon|
# |    1238|  77115|   prior|           4|        1|               11|                   8.0|    1238|                2|        0|       365|     Cheerios Cereal|     121|           14|      breakfast|              cereal|
# |    1238|  77115|   prior|           4|        1|               11|                   8.0|    1238|                3|        1|     39275| Organic Blueberries|     123|            4|        produce|packaged vegetabl...|
# |    1238|  77115|   prior|           4|        1|               11|                   8.0|    1238|                4|        0|     45104|ALMONDBREEZE UNSW...|      91|           16|     dairy eggs|     soy lactosefree|
# |    1238|  77115|   prior|           4|        1|               11|                   8.0|    1238|                5|        0|     33168|Everyday Paper Pl...|     111|           17|      household|plates bowls cups...|
# |    1238|  77115|   prior|           4|        1|               11|                   8.0|    1238|                6|        1|     24674|Dutch Country Pot...|     112|            3|         bakery|               bread|
# |    1238|  77115|   prior|           4|        1|               11|                   8.0|    1238|                7|        0|     37993|Coppertop AA Batt...|      87|           17|      household|      more household|
# |    1238|  77115|   prior|           4|        1|               11|                   8.0|    1238|                8|        0|     44931|   Max AAA Batteries|       6|            2|          other|               other|
# |    1238|  77115|   prior|           4|        1|               11|                   8.0|    1238|                9|        0|     12466|Alkaline C Batteries|      87|           17|      household|      more household|
# |    1580| 132282|   prior|          38|        4|               18|                   6.0|    1580|                1|        1|       329|Organic Whole Gra...|      84|           16|     dairy eggs|                milk|
# |    1580| 132282|   prior|          38|        4|               18|                   6.0|    1580|                2|        1|     37966|French Baguette B...|     112|            3|         bakery|               bread|
# |    1580| 132282|   prior|          38|        4|               18|                   6.0|    1580|                3|        1|     22935|Organic Yellow Onion|      83|            4|        produce|    fresh vegetables|
# |    1580| 132282|   prior|          38|        4|               18|                   6.0|    1580|                4|        1|     41488|      Chocolate Milk|      84|           16|     dairy eggs|                milk|
# |    1580| 132282|   prior|          38|        4|               18|                   6.0|    1580|                5|        1|     21137|Organic Strawberries|      24|            4|        produce|        fresh fruits|
# |    1580| 132282|   prior|          38|        4|               18|                   6.0|    1580|                6|        1|      3539|Chocolate Dark Ch...|      37|            1|         frozen|       ice cream ice|
# |    1580| 132282|   prior|          38|        4|               18|                   6.0|    1580|                7|        1|     27966| Organic Raspberries|     123|            4|        produce|packaged vegetabl...|
# |    1580| 132282|   prior|          38|        4|               18|                   6.0|    1580|                8|        1|      4472|Toasted Coconut A...|      91|           16|     dairy eggs|     soy lactosefree|
# |    1580| 132282|   prior|          38|        4|               18|                   6.0|    1580|                9|        1|     11422|  Plain Greek Yogurt|     120|           16|     dairy eggs|              yogurt|
# |    1580| 132282|   prior|          38|        4|               18|                   6.0|    1580|               10|        1|     26298|Thin Crust Marghe...|      79|            1|         frozen|        frozen pizza|
# |    1580| 132282|   prior|          38|        4|               18|                   6.0|    1580|               11|        1|     19678|Organic Russet Po...|      83|            4|        produce|    fresh vegetables|
# |    1580| 132282|   prior|          38|        4|               18|                   6.0|    1580|               12|        1|      8638|Vanilla Milk Choc...|      37|            1|         frozen|       ice cream ice|
# |    1580| 132282|   prior|          38|        4|               18|                   6.0|    1580|               13|        1|     28842|    Bunched Cilantro|      16|            4|        produce|         fresh herbs|
# |    1645| 193398|   prior|          18|        1|                6|                   7.0|    1645|                1|        1|     28849|No Salt Added Bla...|      59|           15|   canned goods|  canned meals beans|
# |    1645| 193398|   prior|          18|        1|                6|                   7.0|    1645|                2|        1|     19019|Uncured Slow Cook...|      96|           20|           deli|          lunch meat|
# |    1645| 193398|   prior|          18|        1|                6|                   7.0|    1645|                3|        1|     48415|Big California So...|     112|            3|         bakery|               bread|
# |    1645| 193398|   prior|          18|        1|                6|                   7.0|    1645|                4|        1|     21903|Organic Baby Spinach|     123|            4|        produce|packaged vegetabl...|
# |    1645| 193398|   prior|          18|        1|                6|                   7.0|    1645|                5|        1|     21616|Organic Baby Arugula|     123|            4|        produce|packaged vegetabl...|
# |    1645| 193398|   prior|          18|        1|                6|                   7.0|    1645|                6|        1|     38720|Real French Vinai...|      89|           13|         pantry|salad dressing to...|
# |    1645| 193398|   prior|          18|        1|                6|                   7.0|    1645|                7|        1|     41950|Organic Tomato Cl...|      83|            4|        produce|    fresh vegetables|
# |    1645| 193398|   prior|          18|        1|                6|                   7.0|    1645|                8|        1|     40593|        Cream Cheese|     108|           16|     dairy eggs|other creams cheeses|
# |    1645| 193398|   prior|          18|        1|                6|                   7.0|    1645|                9|        1|     22395|        Tomato Sauce|      81|           15|   canned goods|canned jarred veg...|
# |    1829| 205787|   prior|          37|        2|               15|                   7.0|    1829|                1|        1|     47209|Organic Hass Avocado|      24|            4|        produce|        fresh fruits|
# |    1829| 205787|   prior|          37|        2|               15|                   7.0|    1829|                2|        1|     21392|Coffee Cold-Brew ...|      26|            7|      beverages|              coffee|
# |    1829| 205787|   prior|          37|        2|               15|                   7.0|    1829|                3|        1|     38383|Organic White Onions|      83|            4|        produce|    fresh vegetables|
# |    1829| 205787|   prior|          37|        2|               15|                   7.0|    1829|                4|        1|     35042|         Black Beans|      59|           15|   canned goods|  canned meals beans|
# |    1829| 205787|   prior|          37|        2|               15|                   7.0|    1829|                5|        1|     44632|Sparkling Water G...|     115|            7|      beverages|water seltzer spa...|
# |    1829| 205787|   prior|          37|        2|               15|                   7.0|    1829|                6|        1|     45535|Organic Low Sodiu...|      69|           15|   canned goods| soup broth bouillon|
# |    1829| 205787|   prior|          37|        2|               15|                   7.0|    1829|                7|        1|      3142|Organic Short Gra...|      63|            9|dry goods pasta|grains rice dried...|
# |    1829| 205787|   prior|          37|        2|               15|                   7.0|    1829|                8|        1|     21903|Organic Baby Spinach|     123|            4|        produce|packaged vegetabl...|
# |    1829| 205787|   prior|          37|        2|               15|                   7.0|    1829|                9|        1|     27683|Black Beans No Sa...|      59|           15|   canned goods|  canned meals beans|
# |    1959| 146119|   prior|          88|        4|                9|                   1.0|    1959|                1|        1|     32655|Organic Large Gra...|      86|           16|     dairy eggs|                eggs|
# |    1959| 146119|   prior|          88|        4|                9|                   1.0|    1959|                2|        1|     13702|Good Seed Organic...|     112|            3|         bakery|               bread|
# |    1959| 146119|   prior|          88|        4|                9|                   1.0|    1959|                3|        0|      9020|Boneless Skinless...|      35|           12|   meat seafood|     poultry counter|
# |    1959| 146119|   prior|          88|        4|                9|                   1.0|    1959|                4|        0|     44359|Organic Small Bun...|      83|            4|        produce|    fresh vegetables|
# |    1959| 146119|   prior|          88|        4|                9|                   1.0|    1959|                5|        0|     28104|Artisan Roasted C...|      69|           15|   canned goods| soup broth bouillon|
# |    1959| 146119|   prior|          88|        4|                9|                   1.0|    1959|                6|        1|     32467|Organic Living Bu...|      83|            4|        produce|    fresh vegetables|
# |    2122|  86448|   prior|           8|        6|               15|                   5.0|    2122|                1|        1|     33090|Light & Fit Straw...|     120|           16|     dairy eggs|              yogurt|
# |    2122|  86448|   prior|           8|        6|               15|                   5.0|    2122|                2|        1|     23909| 2% Reduced Fat Milk|      84|           16|     dairy eggs|                milk|
# |    2122|  86448|   prior|           8|        6|               15|                   5.0|    2122|                3|        1|       926|Crispy Thin Crust...|      79|            1|         frozen|        frozen pizza|
# |    2122|  86448|   prior|           8|        6|               15|                   5.0|    2122|                4|        0|     49269|13 Gallon Drawstr...|      60|           17|      household|   trash bags liners|
# |    2122|  86448|   prior|           8|        6|               15|                   5.0|    2122|                5|        0|     24810|Organic Lightly S...|      78|           19|         snacks|            crackers|
# |    2142|   2086|   prior|           5|        6|               16|                  12.0|    2142|                1|        0|     26209|               Limes|      24|            4|        produce|        fresh fruits|
# |    2142|   2086|   prior|           5|        6|               16|                  12.0|    2142|                2|        1|     35921|Organic Large Gra...|      86|           16|     dairy eggs|                eggs|
# |    2142|   2086|   prior|           5|        6|               16|                  12.0|    2142|                3|        1|     28842|    Bunched Cilantro|      16|            4|        produce|         fresh herbs|
# |    2142|   2086|   prior|           5|        6|               16|                  12.0|    2142|                4|        1|     28083|Healthy Multi Gra...|     112|            3|         bakery|               bread|
# |    2142|   2086|   prior|           5|        6|               16|                  12.0|    2142|                5|        1|     14553|Oats & Honey Granola|      57|           14|      breakfast|             granola|
# |    2142|   2086|   prior|           5|        6|               16|                  12.0|    2142|                6|        1|     25146|Original Orange J...|      31|            7|      beverages|        refrigerated|
# |    2142|   2086|   prior|           5|        6|               16|                  12.0|    2142|                7|        1|      7644|Scoops! Tortilla ...|     107|           19|         snacks|      chips pretzels|
# +--------+-------+--------+------------+---------+-----------------+----------------------+--------+-----------------+---------+----------+--------------------+--------+-------------+---------------+--------------------+
# only showing top 100 rows

# %%
#Queries for understanding of the Data

spark.sql('Select * From orders where user_id=202279').show(truncate=False)

spark.sql('Select * From order_products__prior where order_id in (Select order_id From orders where user_id=202279)').show(1000,truncate=False)

spark.sql('Select * From order_products__train where order_id in (Select order_id From orders where user_id=202279)').show(1000,truncate=False)

spark.sql('Select product_id From order_products__prior where order_id in (Select order_id From orders where user_id=202279) intersect Select product_id From order_products__train where order_id in (Select order_id From orders where user_id=202279)').show(1000,truncate=False)

# %%
#3.Check missing data
print(sdf.count())

print(order_products__prior.count())

#as from the results it can be soon that in our joining the tables we have diffrence of minute 3 records in such humungous dataset
# so our joining process is perfect
# Out:
# 32434486
# 32434489

# %%
#Note that I have used the individual tables to come out to the results of questions asked , combined sdf table can also be used

# as in the assignment our task was to come out with the results for the question asked not explicitly mentioned to use the combined table

# %%
#4.List the most ordered products (top 10)

#Here using the order_products_prior to calculate the count of the products in various orders and then sort them and get 10

spark.sql('Select product_id , count(product_id) from order_products__prior group by product_id  order by count(product_id)  desc limit 10').show()

spark.sql(' Select product_id , product_name from products where product_id in (Select product_id  from order_products__prior group by product_id  order by count(product_id)  desc limit 10)').show(1000)

spark.sql(' select a.product_id ,a.counts, p.product_name from (Select product_id , count(product_id) as counts from order_products__prior group by product_id  order by count(product_id)  desc limit 10) as a inner join products as p where a.product_id = p.product_id ').show(1000)
# Out:
# +----------+-----------------+
# |product_id|count(product_id)|
# +----------+-----------------+
# |     24852|           472565|
# |     13176|           379450|
# |     21137|           264683|
# |     21903|           241921|
# |     47209|           213584|
# |     47766|           176815|
# |     47626|           152657|
# |     16797|           142951|
# |     26209|           140627|
# |     27845|           137905|
# +----------+-----------------+
#
# +----------+--------------------+
# |product_id|        product_name|
# +----------+--------------------+
# |     13176|Bag of Organic Ba...|
# |     16797|        Strawberries|
# |     21137|Organic Strawberries|
# |     21903|Organic Baby Spinach|
# |     24852|              Banana|
# |     26209|               Limes|
# |     27845|  Organic Whole Milk|
# |     47209|Organic Hass Avocado|
# |     47626|         Large Lemon|
# |     47766|     Organic Avocado|
# +----------+--------------------+
#
# +----------+------+--------------------+
# |product_id|counts|        product_name|
# +----------+------+--------------------+
# |     24852|472565|              Banana|
# |     13176|379450|Bag of Organic Ba...|
# |     21137|264683|Organic Strawberries|
# |     21903|241921|Organic Baby Spinach|
# |     47209|213584|Organic Hass Avocado|
# |     47766|176815|     Organic Avocado|
# |     47626|152657|         Large Lemon|
# |     16797|142951|        Strawberries|
# |     26209|140627|               Limes|
# |     27845|137905|  Organic Whole Milk|
# +----------+------+--------------------+

# %%
#5. Do people usually reorder the same previous ordered products? 

#This can be solved like we can have product wise ordered numbers , reordered numbers , then reorderd/ordered will give us the reordering probability
#reordering probability of each product
#then we can take mean of this reordering probability to get the overall attitude of people to reorder

spark.sql('Select product_id ,count(product_id) as purchase_count , sum(reordered) as reorderd_count , sum(reordered)/count(product_id) as reordering_probability  from order_products__prior group by product_id  order by reordering_probability desc').show()

#Overall mean of the reordering probability will decide the overall attitude of public in reordering

spark.sql('Select avg(a.reordering_probability) as reordering_sentiment from (Select product_id ,count(product_id) as purchase_count , sum(reordered) as reorderd_count , sum(reordered)/count(product_id) as reordering_probability  from order_products__prior group by product_id  order by reordering_probability desc) as a').show()
# Out:
# +----------+--------------+--------------+----------------------+
# |product_id|purchase_count|reorderd_count|reordering_probability|
# +----------+--------------+--------------+----------------------+
# |      6433|            68|            64|    0.9411764705882353|
# |      2075|            87|            81|    0.9310344827586207|
# |     43553|            13|            12|    0.9230769230769231|
# |     27740|           101|            93|    0.9207920792079208|
# |     14609|            35|            32|    0.9142857142857143|
# |     13875|            45|            41|    0.9111111111111111|
# |     39992|            22|            20|    0.9090909090909091|
# |      5868|            30|            27|                   0.9|
# |     35604|           100|            90|                   0.9|
# |     31418|            60|            54|                   0.9|
# |     36543|            67|            60|    0.8955223880597015|
# |     26093|            66|            59|    0.8939393939393939|
# |       700|            28|            25|    0.8928571428571429|
# |      4212|            37|            33|    0.8918918918918919|
# |     38251|           111|            99|    0.8918918918918919|
# |     38438|            27|            24|    0.8888888888888888|
# |     35513|            18|            16|    0.8888888888888888|
# |     36801|            96|            85|    0.8854166666666666|
# |     34246|            52|            46|    0.8846153846153846|
# |     47825|            25|            22|                  0.88|
# +----------+--------------+--------------+----------------------+
# only showing top 20 rows
#
# +--------------------+
# |reordering_sentiment|
# +--------------------+
# | 0.36646101562325384|
# +--------------------+

# %%
#As we can see above the average of reordering probability is 0.37 i.e. around 37 percent so it seems that people usually not reorder the products

# %%
#6. List most reordered products 

# here we sum the reordering value with respect to product_id and then sort in descending order 

spark.sql('Select product_id , sum(reordered) from order_products__prior group by product_id  order by sum(reordered)  desc limit 10').show()


spark.sql(' select a.product_id ,a.reordering_count, p.product_name from (Select product_id , sum(reordered) as reordering_count from order_products__prior group by product_id  order by sum(reordered)  desc limit 10) as a inner join products as p where a.product_id = p.product_id ').show(1000)
# Out:
# +----------+--------------+
# |product_id|sum(reordered)|
# +----------+--------------+
# |     24852|        398609|
# |     13176|        315913|
# |     21137|        205845|
# |     21903|        186884|
# |     47209|        170131|
# |     47766|        134044|
# |     27845|        114510|
# |     47626|        106255|
# |     27966|        105409|
# |     16797|         99802|
# +----------+--------------+
#
# +----------+----------------+--------------------+
# |product_id|reordering_count|        product_name|
# +----------+----------------+--------------------+
# |     24852|          398609|              Banana|
# |     13176|          315913|Bag of Organic Ba...|
# |     21137|          205845|Organic Strawberries|
# |     21903|          186884|Organic Baby Spinach|
# |     47209|          170131|Organic Hass Avocado|
# |     47766|          134044|     Organic Avocado|
# |     27845|          114510|  Organic Whole Milk|
# |     47626|          106255|         Large Lemon|
# |     27966|          105409| Organic Raspberries|
# |     16797|           99802|        Strawberries|
# +----------+----------------+--------------------+

# %%
#7. Most important department and aisle (by number of products)

spark.sql(' Select department_id , department from departments where department_id in (Select department_id  from products group by department_id  order by count(product_id)  desc limit 1)').show(1000)


#spark.sql(' Select aisle_id  from products group by aisle_id  order by count(product_id)  desc limit 1').show(1000)

spark.sql(' Select aisle_id , aisle from aisles where aisle_id in (Select aisle_id  from products group by aisle_id  order by count(product_id)  desc limit 1)').show(1000)
# Out:
# +-------------+-------------+
# |department_id|   department|
# +-------------+-------------+
# |           11|personal care|
# +-------------+-------------+
#
# +--------+-------+
# |aisle_id|  aisle|
# +--------+-------+
# |     100|missing|
# +--------+-------+

# %%
#8. Get the Top 10 departments

#So here the number of products are the deciding factor right

#Through this query we will get the top 10 departments with their names but they will not be in order according to the products
spark.sql(' Select department_id , department from departments where department_id in (Select department_id  from products group by department_id  order by count(product_id)  desc limit 10)').show(1000)


#Here we have the top 10 departments based on the count of products 
spark.sql('Select department_id  , count(product_id) as product_count from products group by department_id  order by count(product_id)  desc limit 10').show()


#Using both queries to make complex query to generate the results
spark.sql('Select d.department_id , d.department , a.product_count from (Select department_id  , count(product_id) as product_count from products group by department_id  order by count(product_id)  desc limit 10) as a inner join departments d where a.department_id = d.department_id ').show()
# Out:
# +-------------+---------------+
# |department_id|     department|
# +-------------+---------------+
# |            1|         frozen|
# |            4|        produce|
# |            7|      beverages|
# |            9|dry goods pasta|
# |           11|  personal care|
# |           13|         pantry|
# |           15|   canned goods|
# |           16|     dairy eggs|
# |           17|      household|
# |           19|         snacks|
# +-------------+---------------+
#
# +-------------+-------------+
# |department_id|product_count|
# +-------------+-------------+
# |           11|         6563|
# |           19|         6264|
# |           13|         5371|
# |            7|         4365|
# |            1|         4007|
# |           16|         3449|
# |           17|         3084|
# |           15|         2092|
# |            9|         1858|
# |            4|         1684|
# +-------------+-------------+
#
# +-------------+---------------+-------------+
# |department_id|     department|product_count|
# +-------------+---------------+-------------+
# |           11|  personal care|         6563|
# |           19|         snacks|         6264|
# |           13|         pantry|         5371|
# |            7|      beverages|         4365|
# |            1|         frozen|         4007|
# |           16|     dairy eggs|         3449|
# |           17|      household|         3084|
# |           15|   canned goods|         2092|
# |            9|dry goods pasta|         1858|
# |            4|        produce|         1684|
# +-------------+---------------+-------------+

# %%
#9. List top 10 products ordered in the morning (6 AM to 11 AM)

spark.sql('Select product_id , count(product_id) from order_products__prior  where order_id in (select distinct order_id from orders where (order_hour_of_day >= 6 and order_hour_of_day <= 11 )) group by product_id  order by count(product_id)  desc limit 10 ').show()

spark.sql(' select a.product_id ,a.order_counts, p.product_name from (Select product_id , count(product_id) as order_counts from order_products__prior  where order_id in (select distinct order_id from orders where (order_hour_of_day >= 6 and order_hour_of_day <= 11 )) group by product_id  order by count(product_id)  desc limit 10 ) as a inner join products as p where a.product_id = p.product_id ').show(1000)
# Out:
# +----------+-----------------+
# |product_id|count(product_id)|
# +----------+-----------------+
# |     24852|           163891|
# |     13176|           130488|
# |     21137|            89015|
# |     21903|            79550|
# |     47209|            70312|
# |     47766|            57311|
# |     47626|            50905|
# |     16797|            49982|
# |     27845|            48124|
# |     27966|            47948|
# +----------+-----------------+
#
# +----------+------------+--------------------+
# |product_id|order_counts|        product_name|
# +----------+------------+--------------------+
# |     24852|      163891|              Banana|
# |     13176|      130488|Bag of Organic Ba...|
# |     21137|       89015|Organic Strawberries|
# |     21903|       79550|Organic Baby Spinach|
# |     47209|       70312|Organic Hass Avocado|
# |     47766|       57311|     Organic Avocado|
# |     47626|       50905|         Large Lemon|
# |     16797|       49982|        Strawberries|
# |     27845|       48124|  Organic Whole Milk|
# |     27966|       47948| Organic Raspberries|
# +----------+------------+--------------------+

# %%
#testing queries to confirm the above results

#spark.sql('Select  order_id from order_products__prior where product_id = 24852').show(10000)
#spark.sql('(Select  order_id from order_products__prior where product_id = 24852) intersect (Select order_id  from orders where order_id in ( Select  order_id from order_products__prior where product_id = 24852) and order_hour_of_day between 6 and 11)').show(10000)
#spark.sql('select order_hour_of_day from orders where order_id=1537').show()
#spark.sql('select product_id from order_products__prior where order_id=1537').show()

# %%
#10. Create a spark-submit application for the same and print the findings in the log


# I have submitted the Jupyter notebook instead of creating the pyspark script and then submitting the pyspark job
